# %% [markdown]
# # Blackjack: UI Layer Testing & Accessibility Audit
#
# **Game**: Blackjack
# **Scope**: UI Components (atoms, molecules, organisms) + WCAG 2.1 AA Compliance
# **Date**: 2026-03-18
# **Status**: Comprehensive Testing & Audit Framework
#
# ---
#
# ## Outline
#
# 1. **Test Environment Setup** — Vitest + Playwright + Testing Library
# 2. **Component Test Suite** — Atoms, Molecules, Organisms
# 3. **E2E & Interaction Tests** — Gameplay flows, user actions
# 4. **Accessibility Audit (WCAG 2.1 AA)** — Keyboard nav, focus, contrast, semantics
# 5. **Compliance Dashboard** — Status, findings, remediation
# 6. **Performance Benchmarks** — Rendering, interaction latency
# 7. **Cross-Device Testing** — Mobile (375px), Tablet (600px), Desktop (900px+)
# 8. **Remediation Plan** — Issues found, fixes, verification

# %% [markdown]
# ## 1. Test Environment Setup
#
# ### Installed Testing Frameworks
#
# | Framework | Version | Purpose | Config |
# |-----------|---------|---------|--------|
# | **Vitest** | 4.0.18 | Unit/integration/component tests | vitest.config.ts |
# | **Playwright** | 1.59.1 | E2E/a11y/visual tests | playwright.config.ts |
# | **@testing-library/react** | 16.3.2 | React component testing | N/A |
# | **axe-core** | 4.x | Accessibility audit | axe-playwright |
#
# ### Test Scripts Available
#
# ```bash
# # Unit, integration, component tests (Vitest)
# pnpm test                    # Run all .test.ts files
# pnpm test:watch             # Watch mode
#
# # E2E and accessibility tests (Playwright)
# pnpm test:e2e               # Run all .spec.ts files
# pnpm test:e2e:ui            # Interactive UI mode
#
# # Test naming validation
# pnpm test:names             # Validate all test names
#
# # Full validation gate
# pnpm validate               # lint + typecheck + test:names + build
# ```
#
# ### Test Naming Convention (Mandatory)
#
# Pattern: `<featureName>.<type>.{test|spec}.ts{x}`
#
# **Framework Mapping**:
# - `.test.ts(x)` = Vitest (unit, integration, component, api)
# - `.spec.ts` = Playwright (e2e, a11y, visual)
#
# ### Valid Test Types
#
# | Type | Framework | Use Case | Examples |
# |------|-----------|----------|----------|
# | unit | Vitest | Pure function testing | card.unit.test.ts |
# | integration | Vitest | Hook + service testing | deal-hand.integration.test.ts |
# | component | Vitest | React component testing | Button.component.test.tsx |
# | api | Vitest | API client/mocking | deck-api.api.test.ts |
# | e2e | Playwright | Full user flows | gameplay.e2e.spec.ts |
# | a11y | Playwright | Accessibility testing | keyboard-nav.a11y.spec.ts |
# | visual | Playwright | Visual regression | theme.visual.spec.ts |
# | perf | Vitest | Performance benchmarks | board-render.perf.test.ts |

# %% [markdown]
# ## 2. Component Test Suite
#
# ### 2.1 Atoms (Elementary building blocks)
#
# **Scope**: Buttons, inputs, labels, cards, badges, icons
#
# | Component | Test File | Coverage | Status |
# |-----------|-----------|----------|--------|
# | **Button** | Button.component.test.tsx | Variants, disabled, loading, onClick | ⚠️ To Build |
# | **Card** | Card.component.test.tsx | Layout, shadow, hover | ⚠️ To Build |
# | **Badge** | Badge.component.test.tsx | Color variants, sizes | ⚠️ To Build |
# | **Icon** | Icon.component.test.tsx | Rendering, sizing, color | ⚠️ To Build |
# | **Label** | Label.component.test.tsx | Text, accessibility, focus | ⚠️ To Build |
#
# **Test Checklist for Atoms**:
#
# - [ ] Renders without errors (happy path)
# - [ ] Accepts all required props
# - [ ] Accepts all optional props
# - [ ] CSS classes applied correctly
# - [ ] Event handlers fire (onClick, onFocus, etc.)
# - [ ] Accessibility attributes present (aria-label, role)
# - [ ] Keyboard support (Tab, Enter, Space)
# - [ ] Focus visible (keyboard navigation)
# - [ ] Touch targets ≥44px on mobile
# - [ ] Responsive sizing applied
#
# ### 2.2 Molecules (Atom groups)
#
# **Scope**: Form groups, menu items, status displays, button groups
#
# | Component | Test File | Coverage | Status |
# |-----------|-----------|----------|--------|
# | **CardField** | CardField.component.test.tsx | Display card, suit, rank | ⚠️ To Build |
# | **Chip** | Chip.component.test.tsx | Selection state, disabled | ⚠️ To Build |
# | **HandDisplay** | HandDisplay.component.test.tsx | Multiple cards, total | ⚠️ To Build |
# | **StatusMessage** | StatusMessage.component.test.tsx | Message types, animations | ⚠️ To Build |
# | **GameControls** | GameControls.component.test.tsx | Hit/Stand/Double buttons | ⚠️ To Build |
#
# **Test Checklist for Molecules**:
#
# - [ ] Composes atoms correctly
# - [ ] Manages local component state
# - [ ] Accepts callback props
# - [ ] Forwards accessibility to child atoms
# - [ ] Responsive layout adapts per device
# - [ ] Focus management works through child atoms
# - [ ] Keyboard nav traverses molecule
# - [ ] Touch optimization applied
#
# ### 2.3 Organisms (Feature components)
#
# **Scope**: Game board, settings modal, results table, main menu, hamburger menu
#
# | Component | Test File | Coverage | Status |
# |-----------|-----------|----------|--------|
# | **GameBoard** | GameBoard.component.test.tsx | Deal, hit/stand, messages | ⚠️ To Build |
# | **SettingsModal** | SettingsModal.component.test.tsx | Form inputs, OK/Cancel | ⚠️ To Build |
# | **ResultsTable** | ResultsTable.component.test.tsx | Sorting, filtering, navigation | ⚠️ To Build |
# | **MainMenu** | MainMenu.component.test.tsx | Navigation, buttons | ⚠️ To Build |
# | **HamburgerMenu** | HamburgerMenu.component.test.tsx | Open/close, focus trap | ⚠️ To Build |
# | **StatusBar** | StatusBar.component.test.tsx | Score, dealer info display | ⚠️ To Build |
#
# **Test Checklist for Organisms**:
#
# - [ ] Integrates with app hooks (useTheme, useResponsiveState)
# - [ ] Handles business logic correctly
# - [ ] State management (local + context) works
# - [ ] Interaction flows complete (gameplay loop)
# - [ ] Error handling displays (validation, API errors)
# - [ ] Loading states show
# - [ ] Focus management across child components
# - [ ] Keyboard nav works end-to-end
# - [ ] Responsive across all 5 device tiers

# %% [markdown]
# ## 3. E2E & Interaction Tests
#
# ### 3.1 Gameplay Flow Tests (E2E)
#
# **File**: `gameplay.e2e.spec.ts`
#
# ```typescript
# // Scenarios to test:
# describe('Blackjack Gameplay Flow', () => {
#   // New game initialization
#   it('should deal initial hand to player and dealer')
#   it('should show correct initial values')
#   it('should set up betting interface')
#
#   // Player actions
#   it('should allow player to hit and receive card')
#   it('should allow player to stand and dealer to play')
#   it('should allow player to double down')
#   it('should prevent invalid actions based on game state')
#
#   // Dealer play
#   it('should follow proper dealer strategy')
#   it('should dealer hit on <17, stand on >=17')
#
#   // Win/loss conditions
#   it('should detect blackjack')
#   it('should detect bust')
#   it('should determine winner correctly')
#   it('should display results message')
#
#   // Game reset
#   it('should reset game for new round')
# })
# ```
#
# ### 3.2 User Interaction Tests (E2E)
#
# **File**: `user-interactions.e2e.spec.ts`
#
# ```typescript
# // Test user actions:
# describe('User Interactions', () => {
#   // Mouse/touch interactions
#   it('should handle button clicks')
#   it('should handle card selection')
#   it('should handle menu navigation')
#   it('should open/close modals')
#
#   // Keyboard navigation
#   it('should use arrow keys to navigate')
#   it('should use Enter to confirm')
#   it('should use Escape to cancel')
#
#   // Device-specific
#   it('should work on mobile (375px)')
#   it('should work on tablet (600px)')
#   it('should work on desktop (900px+)')
# })
# ```
#
# ### 3.3 Settings & Configuration Tests (E2E)
#
# **File**: `settings.e2e.spec.ts`
#
# ```typescript
# describe('Settings & Configuration', () => {
#   it('should open settings modal from home')
#   it('should change difficulty setting')
#   it('should change theme setting')
#   it('should toggle sound on/off')
#   it('should apply and persist settings')
#   it('should cancel settings without changes')
# })
# ```
#
# ### 3.4 Navigation & Menu Tests (E2E)
#
# **File**: `navigation.e2e.spec.ts`
#
# ```typescript
# describe('Navigation & Menus', () => {
#   it('should navigate from home to game')
#   it('should open hamburger menu during gameplay')
#   it('should navigate menu items')
#   it('should close menu on click outside')
#   it('should return to home from game')
#   it('should access results from menu')
# })
# ```

# %% [markdown]
# ## 4. Accessibility Audit (WCAG 2.1 AA)
#
# ### 4.1 Keyboard Navigation
#
# **File**: `keyboard-nav.a11y.spec.ts`
#
# **Requirements** (WCAG 2.1 AA):
#
# | Requirement | Expected | Status |
# |-------------|----------|--------|
# | All interactive elements keyboard accessible | TAB reaches all buttons/inputs | ⚠️ Audit |
# | Logical tab order | Tab order matches visual left-to-right, top-to-bottom | ⚠️ Audit |
# | Focus indicator visible | Focus ring/highlight clearly visible (≥3:1 contrast) | ⚠️ Audit |
# | Focus trap in modals | Focus doesn't escape from modal (Settings, Game Over) | ⚠️ Audit |
# | Escape closes modals | ESC key dismisses open modals | ⚠️ Audit |
# | Enter confirms actions | ENTER activates buttons, inputs | ⚠️ Audit |
# | Space activates buttons | SPACE activates checkboxes, toggles, buttons | ⚠️ Audit |
# | Arrow keys navigate lists | UP/DOWN traverse menu items, card options | ⚠️ Audit |
# | No keyboard trap | User can move focus away from any element | ⚠️ Audit |
# | Focus on modal open | Focus moves to first interactive element in modal | ⚠️ Audit |
# | Focus restored on close | Focus returns to trigger button when modal closes | ⚠️ Audit |
#
# **Test Template**:
#
# ```typescript
# describe('Keyboard Navigation', () => {
#   it('should allow tabbing through all interactive elements')
#   it('should show visible focus indicator on every element')
#   it('should follow logical tab order (left-to-right, top-to-bottom)')
#   it('should trap focus within modal while open')
#   it('should release focus when modal closes')
#   it('should allow Escape to close modals')
#   it('should allow Enter to activate buttons')
#   it('should allow Space to toggle checkboxes')
#   it('should not have keyboard traps')
#   it('should support arrow key navigation in menus')
# })
# ```
#
# ### 4.2 Focus Management
#
# **File**: `focus-management.a11y.spec.ts`
#
# | Requirement | Expected | Status |
# |-------------|----------|--------|
# | Focus visible on all interactive | Every button, input, link has visible :focus style | ⚠️ Audit |
# | Focus contrast ≥3:1 | Focus indicator contrast against background | ⚠️ Audit |
# | Focus not hidden by content | No elements overlay focus ring | ⚠️ Audit |
# | Focus receives relative position | `position: relative` on focusable elements | ⚠️ Audit |
# | Focus z-index sufficient | Focus rings visible above content (z-index stacking) | ⚠️ Audit |
# | Initial focus correct | Page loads with focus on appropriate element (logo vs first input) | ⚠️ Audit |
#
# ### 4.3 Color Contrast
#
# **File**: `contrast.a11y.spec.ts`
#
# | Element | Requirement | Status |
# |---------|-------------|--------|
# | Text | ≥4.5:1 (normal), ≥3:1 (large 18pt+) | ⚠️ Audit |
# | Buttons | ≥4.5:1 text + border | ⚠️ Audit |
# | Focus indicator | ≥3:1 against background | ⚠️ Audit |
# | Icons as text | ≥4.5:1 | ⚠️ Audit |
# | Disabled elements | Can be ≥3:1 (exception) | ⚠️ Audit |
# | Links | ≥4.5:1 + not color-only (underline or icon) | ⚠️ Audit |
#
# ### 4.4 Semantic HTML & ARIA
#
# **File**: `semantics.a11y.spec.ts`
#
# | Element | Expected | Status |
# |---------|----------|--------|
# | Buttons | `<button>` tag, not `<div onclick>` | ⚠️ Audit |
# | Links | `<a>` tag with href, not `<div onclick>` | ⚠️ Audit |
# | Form fields | `<input>` with `<label for="id">` | ⚠️ Audit |
# | Headings | `<h1-h6>` structure (no skipped levels) | ⚠️ Audit |
# | Lists | `<ul>`/`<ol>`/`<li>` for list content | ⚠️ Audit |
# | Tables | `<table>`, `<th>`, `<td>` with scope attr | ⚠️ Audit |
# | Modals | `role="dialog"`, `aria-modal="true"`, `aria-labelledby` | ⚠️ Audit |
# | Icons | `aria-hidden="true"` if decorative, `aria-label` if functional | ⚠️ Audit |
# | Status messages | `aria-live="polite"` for dynamic updates | ⚠️ Audit |
# | Form errors | `aria-invalid="true"`, error text linked via `aria-describedby` | ⚠️ Audit |
#
# ### 4.5 Accessibility Audit with axe-core
#
# **File**: `axe-audit.a11y.spec.ts`
#
# ```typescript
# import { injectAxe, checkA11y } from 'axe-playwright'
#
# describe('axe Accessibility Audit', () => {
#   beforeEach(async ({ page }) => {
#     await page.goto('http://localhost:5173')
#     await injectAxe(page)
#   })
#
#   it('should not have any accessibility violations on home page', async ({ page }) => {
#     await checkA11y(page, null, {
#       detailedReport: true,
#       detailedReportOptions: {
#         html: true
#       }
#     })
#   })
#
#   it('should not have violations on gameplay screen', async ({ page }) => {
#     // Navigate to game
#     // Check accessibility
#   })
#
#   it('should not have violations on settings modal', async ({ page }) => {
#     // Open settings
#     // Check accessibility
#   })
#
#   // Reports will highlight:
#   // - Violations (must fix)
#   // - Warnings (review, likely need fix)
#   // - Passes (good!)
# })
# ```

# %% [markdown]
# ## 5. Compliance Dashboard
#
# ### 5.1 Test Coverage Summary
#
# ```
# Component Test Coverage
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# Atoms:        0/5   tests (0%)    ⚠️ TO BUILD
# Molecules:    0/5   tests (0%)    ⚠️ TO BUILD
# Organisms:    0/6   tests (0%)    ⚠️ TO BUILD
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# E2E Testing Coverage
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# Gameplay Flow:    0/7   tests (0%)    ⚠️ TO BUILD
# User Interactions: 0/6   tests (0%)    ⚠️ TO BUILD
# Settings:        0/6   tests (0%)    ⚠️ TO BUILD
# Navigation:      0/6   tests (0%)    ⚠️ TO BUILD
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# Accessibility (WCAG 2.1 AA) Coverage
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# Keyboard Nav:      0/11  tests (0%)    ⚠️ TO BUILD
# Focus Management:  0/6   tests (0%)    ⚠️ TO BUILD
# Color Contrast:    0/6   elements      ⚠️ TO AUDIT
# Semantics:         0/10  elements      ⚠️ TO AUDIT
# axe-core Audit:    0 passes            ⚠️ TO RUN
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# ```
#
# ### 5.2 Compliance Status Matrix
#
# | Category | Target | Current | Status | Notes |
# |----------|--------|---------|--------|-------|
# | **Component Tests (Unit/Integration/Component)** | 100% | 0% | 🔴 NOT STARTED | Create test files for all atoms/molecules/organisms |
# | **E2E Tests** | 100% | 0% | 🔴 NOT STARTED | Build gameplay flow, interaction, settings tests |
# | **Accessibility Tests** | 100% | 0% | 🔴 NOT STARTED | Write keyboard nav, focus, semantics tests |
# | **axe Audit** | 0 violations | Unknown | 🟡 PENDING | Run after code fixes |
# | **Keyboard Navigation** | ✅ Full support | ⚠️ Partial | 🟡 IN PROGRESS | Verify all interactive elements accessible |
# | **Focus Management** | ✅ Visible on all | ⚠️ Partial | 🟡 IN PROGRESS | Check focus rings visible, proper styling |
# | **Color Contrast** | ✅ ≥4.5:1 | ⚠️ Not verified | 🟡 TO AUDIT | Run contrast checker on all elements |
# | **Semantic HTML** | ✅ All proper tags | ⚠️ Partial | 🟡 IN PROGRESS | Verify button, link, form, ARIA usage |
# | **Mobile Testing** | ✅ Works on 375px | ⚠️ Not verified | 🟡 TO TEST | Test on 375px, 600px, 900px+ viewports |
# | **Cross-Device Testing** | ✅ Web, Electron, Capacitor | ⚠️ Not verified | 🟡 TO TEST | Run tests on all platforms |
#
# ### 5.3 Priority Issues (To Be Identified in Audit)
#
# | Issue | Severity | Category | Resolution |
# |-------|----------|----------|-----------|
# | *Pending audit* | - | - | - |

# %% [markdown]
# ## 6. Performance Benchmarks
#
# ### 6.1 Rendering Performance
#
# **File**: `rendering.perf.test.ts`
#
# ```typescript
# describe('Rendering Performance', () => {
#   it('should render GameBoard in <50ms', () => {
#     const start = performance.now()
#     render(<GameBoard {...props} />)
#     const end = performance.now()
#     expect(end - start).toBeLessThan(50)
#   })
#
#   it('should render HandDisplay (5 cards) in <30ms', () => {
#     // Test card rendering performance
#   })
#
#   it('should re-render on state change in <30ms', () => {
#     // Test update performance
#   })
# })
# ```
#
# ### 6.2 Interaction Latency
#
# | Interaction | Target | Current | Status |
# |-------------|--------|---------|--------|
# | Button click → state update | <16ms (1 frame @ 60fps) | ⚠️ Untested | 🔴 TO MEASURE |
# | Card dealt → rendered | <100ms | ⚠️ Untested | 🔴 TO MEASURE |
# | Game over → modal shown | <50ms | ⚠️ Untested | 🔴 TO MEASURE |
# | Settings open → modal appears | <200ms | ⚠️ Untested | 🔴 TO MEASURE |
# | Page load → interactive | <2s (Largest Contentful Paint) | ⚠️ Untested | 🔴 TO MEASURE |
#
# ### 6.3 Bundle Size
#
# | Metric | Target | Current | Status |
# |--------|--------|---------|--------|
# | Total JS bundle | <150KB (gzipped) | ⚠️ Untested | 🔴 TO MEASURE |
# | Initial CSS | <50KB (gzipped) | ⚠️ Untested | 🔴 TO MEASURE |
# | Theme CSS (light) | <20KB | ⚠️ Untested | 🔴 TO MEASURE |
# | Theme CSS (dark) | <20KB | ⚠️ Untested | 🔴 TO MEASURE |
#
# ### 6.4 Memory Usage
#
# | Metric | Target | Current | Status |
# |--------|--------|---------|--------|
# | Heap size on load | <20MB | ⚠️ Untested | 🔴 TO MEASURE |
# | After 10 games | <30MB | ⚠️ Untested | 🔴 TO MEASURE |
# | No memory leak (5 min gameplay) | Stable heap | ⚠️ Untested | 🔴 TO MEASURE |

# %% [markdown]
# ## 7. Cross-Device Testing
#
# ### 7.1 Responsive Breakpoint Testing
#
# **Framework**: Playwright (visual + e2e)
#
# **Breakpoints to Test** (5-tier semantic architecture):
#
# | Tier | Width | Device | Expected | Status |
# |------|-------|--------|----------|--------|
# | **Mobile (xs)** | 320px | iPhone SE | Single column, compact spacing | ⚠️ TO TEST |
# | **Mobile (sm)** | 375px | iPhone 12 | Single column, standard spacing | ⚠️ TO TEST |
# | **Tablet (md)** | 600px | iPad mini | 2-column where appropriate, balanced | ⚠️ TO TEST |
# | **Desktop (lg)** | 900px | MacBook Air | Full layout, comfortable spacing | ⚠️ TO TEST |
# | **Widescreen (xl)** | 1200px | Large monitor | Extra spacing, generous UI | ⚠️ TO TEST |
# | **Ultrawide (xxl)** | 1800px | Curved monitor | Maximum refinement, premium spacing | ⚠️ TO TEST |
#
# ### 7.2 Responsive Test File Template
#
# **File**: `responsive.e2e.spec.ts`
#
# ```typescript
# describe.each([
#   { width: 375, height: 812, name: 'Mobile (375px)', tier: 'mobile' },
#   { width: 600, height: 800, name: 'Tablet (600px)', tier: 'tablet' },
#   { width: 900, height: 1080, name: 'Desktop (900px)', tier: 'desktop' },
#   { width: 1200, height: 1080, name: 'Widescreen (1200px)', tier: 'widescreen' },
#   { width: 1800, height: 1080, name: 'Ultrawide (1800px)', tier: 'ultrawide' }
# ])('Responsive Testing - $name', ({ width, height }) => {
#   beforeEach(async ({ page }) => {
#     await page.setViewportSize({ width, height })
#   })
#
#   it('should render game board fully visible', async ({ page }) => {
#     // Navigate to game
#     // Verify board not scrolling vertically
#   })
#
#   it('should show status properly positioned', async ({ page }) => {
#     // Verify top status bar readable
#   })
#
#   it('should have touchable buttons (≥44px)', async ({ page }) => {
#     // Verify button size sufficient for tier
#   })
#
#   it('should wrap/adapt layout for tier', async ({ page }) => {
#     // Verify responsive styles applied
#   })
#
#   it('should not have cutoff/overflow elements', async ({ page }) => {
#     // Verify content fits within viewport
#   })
# })
# ```
#
# ### 7.3 Content Density Testing
#
# **Per-Tier Content Density Expectations**:
#
# | Tier | Content Density | Spacing | Font | Status |
# |------|-----------------|---------|------|--------|
# | Mobile (xs/sm) | Compact | Min padding | 12-14px | ⚠️ TO VERIFY |
# | Tablet (md) | Comfortable | Standard | 14-16px | ⚠️ TO VERIFY |
# | Desktop (lg) | Comfortable | Standard | 16-18px | ⚠️ TO VERIFY |
# | Widescreen (xl) | Spacious | Extra padding | 18-20px | ⚠️ TO VERIFY |
# | Ultrawide (xxl) | Spacious | Premium spacing | 18-20px | ⚠️ TO VERIFY |
#
# **Test**:
#
# ```typescript
# it('should apply correct content density per breakpoint', async ({ page }) => {
#   // For each breakpoint:
#   // 1. Set viewport
#   // 2. Get computed styles
#   // 3. Verify padding, font-size, gap match expected for tier
# })
# ```
#
# ### 7.4 Touch Device Testing
#
# **File**: `touch.e2e.spec.ts`
#
# ```typescript
# describe('Touch Device Interactions', () => {
#   beforeEach(async ({ page }) => {
#     // Simulate touch device (coarse pointer)
#     await page.emulate({ hasTouch: true })
#   })
#
#   it('should disable :hover effects on touch devices', async ({ page }) => {
#     // Check computed styles show no transform/shadow on hover
#   })
#
#   it('should support long-press for context menus', async ({ page }) => {
#     // Test long-press behavior (if applicable)
#   })
#
#   it('should handle swipe gestures (if applicable)', async ({ page }) => {
#     // Test swipe card dealing, etc.
#   })
#
#   it('should not show hover tooltips on touch', async ({ page }) => {
#     // Verify tooltips don't appear on touch hover
#   })
# })
# ```
#
# ### 7.5 Platform-Specific Testing
#
# **Web (Vite dev server)**:
#
# - Test in Chrome, Firefox, Safari
# - Verify responsive behavior
# - Test keyboard + mouse
#
# **Electron (Desktop)**:
#
# - Test window resize responsiveness
# - Verify fullscreen behavior
# - Test native shortcuts (Cmd/Ctrl+Q, etc.)
#
# **Capacitor (Mobile)**:
#
# - Test on iOS Safari
# - Test on Chrome Android
# - Test status bar + notch handling
# - Verify vertical orientation lock if needed

# %% [markdown]
# ## 8. Remediation Plan
#
# ### 8.1 Issue Tracking Template
#
# **Priority Levels**:
#
# | Level | Criteria | Timeline |
# |-------|----------|----------|
# | 🔴 **Critical** | Blocks gameplay, breaks accessibility, security | Immediate |
# | 🟠 **High** | Major UX impact, fails WCAG AA requirement | This week |
# | 🟡 **Medium** | Noticeable but doesn't block, minor WCAG issue | Next sprint |
# | 🟢 **Low** | Nice to have, minor polish, low WCAG impact | Backlog |
#
# ### 8.2 Issues Found & Remediation Status
#
# | ID | Issue | Category | Severity | Status | Fix | Verification |
# |----|-------|----------|----------|--------|-----|--------------|
# | *Pending* | *To be filled during audit* | - | - | - | - | - |
#
# ### 8.3 Remediation Workflow
#
# **For Each Issue Found**:
#
# 1. **Document Issue**
#    - Describe behavior
#    - Note reproduction steps
#    - Assign severity
#
# 2. **Plan Fix**
#    - Identify root cause
#    - Choose solution approach
#    - Estimate effort
#
# 3. **Implement Fix**
#    - Update component code
#    - Add/update tests
#    - Verify fix resolves issue
#
# 4. **Verify Fix**
#    - Run affected test suite
#    - Run accessibility audit again
#    - Cross-device testing
#    - Performance regression check
#
# 5. **Document Fix**
#    - Update issue tracker
#    - Note what changed
#    - Reference PR/commit
#
# ### 8.4 Common Accessibility Fixes
#
# **Keyboard Navigation**:
#
# ```typescript
# // Fix: Make interactive elements keyboard-accessible
# - Change from: <div onClick={handler}>
# - Change to:  <button onClick={handler}>
#
# // Fix: Show focus indicator
# .button:focus-visible {
#   outline: 3px solid #0087BE;
#   outline-offset: 2px;
# }
# ```
#
# **Focus Management**:
#
# ```typescript
# // Fix: Focus on modal open
# const modalRef = useRef<HTMLDivElement>(null)
# useEffect(() => {
#   if (open && modalRef.current) {
#     const firstButton = modalRef.current.querySelector('button')
#     firstButton?.focus()
#   }
# }, [open])
#
# // Fix: Close modal with Escape
# const handleKeyDown = (e: KeyboardEvent) => {
#   if (e.key === 'Escape') {
#     closeModal()
#     triggerRef.current?.focus() // Return focus
#   }
# }
# ```
#
# **Color Contrast**:
#
# ```css
# /* Fix: Ensure text contrast is ≥4.5:1 */
# .button {
#   color: #FFFFFF;           /* White text */
#   background: #0087BE;      /* Dark blue bg */
#   /* Contrast: ~8:1 ✅ */
# }
#
# /* Fix: Focus indicator contrast */
# .button:focus-visible {
#   outline: 3px solid #FFB81C; /* High contrast yellow */
#   /* Contrast vs blue: ~8:1 ✅ */
# }
# ```
#
# **Semantic HTML**:
#
# ```typescript
# // Fix: Use proper semantic elements
# - Instead: <div role="button">Click me</div>
# - Use:     <button>Click me</button>
#
# - Instead: <div role="link" onclick={navigate}>
# - Use:     <a href="/path">Link</a>
#
# - Instead: <div role="heading">Page Title</div>
# - Use:     <h1>Page Title</h1>
# ```
#
# **ARIA Attributes**:
#
# ```typescript
# // Fix: Label form fields
# <label htmlFor="difficulty">Difficulty:</label>
# <select id="difficulty">
#   <option value="easy">Easy</option>
#   <option value="hard">Hard</option>
# </select>
#
# // Fix: Modal accessibility
# <div role="dialog" aria-modal="true" aria-labelledby="modal-title">
#   <h2 id="modal-title">Settings</h2>
#   {/* content */}
# </div>
#
# // Fix: Status messages
# <div aria-live="polite" aria-atomic="true">
#   Game Over! You won!
# </div>
# ```
#
# ### 8.5 Regression Prevention
#
# **After Each Fix**:
#
# 1. ✅ Run `pnpm test` (verify tests still pass)
# 2. ✅ Run `pnpm test:e2e` (verify E2E still works)
# 3. ✅ Run Playwright accessibility tests
# 4. ✅ Run axe-core audit
# 5. ✅ Manual visual inspection at 3 breakpoints
# 6. ✅ Keyboard navigation re-test
#
# **No fix is complete until**:
#
# - ✅ Relevant test passes
# - ✅ Accessibility audit passes
# - ✅ No new violations introduced
# - ✅ Performance not regressed
# - ✅ Responsive behavior preserved

# %% [markdown]
# ## 9. How to Run Tests
#
# ### 9.1 Unit/Integration/Component Tests
#
# ```bash
# # Run all tests
# pnpm --filter @games/blackjack test
#
# # Run specific test file
# pnpm --filter @games/blackjack test Button.component.test.tsx
#
# # Watch mode (re-run on file change)
# pnpm --filter @games/blackjack test:watch
#
# # Generate coverage report
# pnpm --filter @games/blackjack test:coverage
# ```
#
# ### 9.2 E2E & Accessibility Tests
#
# ```bash
# # Run all E2E and accessibility tests
# pnpm --filter @games/blackjack test:e2e
#
# # Run specific test file
# pnpm --filter @games/blackjack test:e2e keyboard-nav.a11y.spec.ts
#
# # Run in interactive UI mode (see what's happening)
# pnpm --filter @games/blackjack test:e2e:ui
#
# # Run with headed browser (see browser window)
# pnpm --filter @games/blackjack test:e2e --headed
# ```
#
# ### 9.3 Validation & Quality Gates
#
# ```bash
# # Full validation gate (lint + format + typecheck + test:names + build)
# pnpm --filter @games/blackjack validate
#
# # Just run tests
# pnpm --filter @games/blackjack test
#
# # Just run E2E tests
# pnpm --filter @games/blackjack test:e2e
# ```
#
# ### 9.4 Accessibility Audit with axe-core
#
# ```bash
# # Install axe-playwright if not already installed
# pnpm --filter @games/blackjack add -D @axe-core/playwright
#
# # Run tests with axe checks
# pnpm --filter @games/blackjack test:e2e axe-audit.a11y.spec.ts
#
# # Results will be in test report
# # Check playwright-report/ directory for detailed HTML report
# ```
#
# ### 9.5 Manual Testing Checklist
#
# **Before Running Automated Tests**:
#
# - [ ] Code builds without errors: `pnpm --filter @games/blackjack build`
# - [ ] App runs locally: `pnpm --filter @games/blackjack start`
# - [ ] No console errors in dev tools
# - [ ] All interactive elements are keyboard-accessible
#
# **During Automated Testing**:
#
# - [ ] All components render correctly
# - [ ] All tests pass (0 failures)
# - [ ] No console warnings related to accessibility
# - [ ] Coverage report shows adequate coverage (>80%)
#
# **After Testing**:
#
# - [ ] Review Playwright HTML report
# - [ ] Review axe audit violations
# - [ ] Review coverage gaps
# - [ ] File issues for any failures

# %% [markdown]
# ## 10. Resources & References
#
# ### 10.1 Testing Frameworks Documentation
#
# | Framework | Docs | Key Features |
# |-----------|------|--------------|
# | **Vitest** | https://vitest.dev | Unit/integration/component testing, extremely fast, Vite-native |
# | **Playwright** | https://playwright.dev | E2E/a11y/visual testing, multiple browsers, headed/headless |
# | **Testing Library** | https://testing-library.com/react | React component testing, user-centric, best practices |
# | **axe-core** | https://github.com/dequelabs/axe-core | Accessibility testing, WCAG compliance |
# | **axe-playwright** | https://github.com/dequelabs/axe-core-npm | axe integration with Playwright |
#
# ### 10.2 Accessibility Standards
#
# | Standard | Link | What It Is |
# |----------|------|-----------|
# | **WCAG 2.1** | https://www.w3.org/WAI/WCAG21/quickref/ | Web Content Accessibility Guidelines Level AA |
# | **ARIA** | https://www.w3.org/WAI/ARIA/apg/ | Accessible Rich Internet Applications authoring practices |
# | **MDN Accessibility** | https://developer.mozilla.org/en-US/docs/Web/Accessibility | Comprehensive accessibility guide |
# | **WAI-ARIA Roles** | https://developer.mozilla.org/en-US/docs/Web/Accessibility/ARIA/Roles | Complete role reference |
#
# ### 10.3 Project-Specific Guidance
#
# | Document | Purpose |
# |----------|---------|
# | `.github/instructions/17-testing.instructions.md` | Platform testing standards, all 8 test types |
# | `.github/instructions/09-wcag-accessibility.instructions.md` | WCAG 2.1 AA compliance requirements |
# | `.github/instructions/06-responsive.instructions.md` | Responsive design 5-tier architecture |
# | `AGENTS.md § 23` | System role, execution context, non-negotiable rules |
# | `AGENTS.md § 12` | Responsive design governance |
# | `AGENTS.md § 28` | Testing governance (MANDATORY) |
#
# ### 10.4 Tool Installation & Setup
#
# **All tools already configured**:
#
# - ✅ Vitest: `vitest.config.ts`
# - ✅ Playwright: `playwright.config.ts`
# - ✅ Testing Library: `package.json` dependencies
# - ✅ axe-core: Ready to use
#
# **To install axe-playwright** (if needed):
#
# ```bash
# cd apps/blackjack
# pnpm add -D @axe-core/playwright
# ```
#
# ### 10.5 Common Commands Reference
#
# ```bash
# # From workspace root
# pnpm --filter @games/blackjack <command>
#
# # From app directory (apps/blackjack/)
# pnpm <command>
#
# # Test-related commands
# pnpm test                  # Run unit/integration/component/api tests
# pnpm test:watch           # Watch mode
# pnpm test:e2e             # Run E2E/a11y/visual tests
# pnpm test:e2e:ui          # Interactive UI mode
# pnpm test:names           # Validate test file names
# pnpm test:coverage        # Generate coverage report
#
# # Quality gates
# pnpm check                # lint + format:check + typecheck
# pnpm fix                  # lint:fix + format
# pnpm validate             # Full gate (check + build + test:names)
#
# # Development
# pnpm start                # Dev server
# pnpm build                # Production build
# pnpm preview              # Preview production build
#
# # For Electron/Capacitor
# pnpm electron:dev         # Electron dev mode
# pnpm cap:sync             # Sync to Capacitor
# ```
#
# ### 10.6 Expected Test File Structure
#
# ```
# apps/blackjack/src/
# ├── ui/
# │   ├── atoms/
# │   │   ├── Button/
# │   │   │   ├── Button.tsx
# │   │   │   ├── Button.component.test.tsx  ✅ Test file
# │   │   │   └── Button.module.css
# │   │   └── ...
# │   ├── molecules/
# │   │   ├── CardField/
# │   │   │   ├── CardField.tsx
# │   │   │   ├── CardField.component.test.tsx  ✅ Test file
# │   │   │   └── CardField.module.css
# │   │   └── ...
# │   └── organisms/
# │       ├── GameBoard/
# │       │   ├── GameBoard.tsx
# │       │   ├── GameBoard.component.test.tsx  ✅ Test file
# │       │   └── GameBoard.module.css
# │       └── ...
# ├── tests/
# │   ├── e2e/
# │   │   ├── gameplay.e2e.spec.ts            ✅ E2E test
# │   │   ├── keyboard-nav.a11y.spec.ts       ✅ A11y test
# │   │   ├── responsive.e2e.spec.ts          ✅ Responsive test
# │   │   └── ...
# │   └── ...
# └── ...
# ```
#
# ### 10.7 Verification Checklist
#
# **Before Submitting Tests**:
#
# - [ ] All test files named correctly (`<feature>.<type>.test{|spec}.ts{x}`)
# - [ ] `pnpm test:names` passes (naming validation)
# - [ ] All tests pass: `pnpm test && pnpm test:e2e`
# - [ ] No console errors or warnings in test output
# - [ ] Coverage report acceptable (>80% for critical code)
# - [ ] Accessibility audit passes (0 violations in axe)
# - [ ] Responsive tests pass on all 5 breakpoints
# - [ ] Performance benchmarks within targets
# - [ ] Full validation passes: `pnpm validate`
#
# **After Final Approval**:
#
# - [ ] Create GitHub PR with test results
# - [ ] Link to Playwright HTML report
# - [ ] Link to coverage report
# - [ ] Document any issues found + remediation plan

# %% [markdown]
# ## 11. Executive Summary & Status Report
#
# ### 11.1 Audit Scope
#
# **Game**: Blackjack
# **Framework**: React 19 + TypeScript + Vite
# **Platforms**: Web, Electron, Capacitor (iOS/Android)
# **Accessibility Standard**: WCAG 2.1 AA (Level 2)
# **Test Frameworks**: Vitest + Playwright
#
# ### 11.2 Current Status
#
# ```
# COMPONENT TESTING
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# Atoms (5 components):              🔴 NOT STARTED (0/5)
# Molecules (5 components):          🔴 NOT STARTED (0/5)
# Organisms (6 components):          🔴 NOT STARTED (0/6)
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# Total Component Tests:             🔴 NOT STARTED (0/16)
#
# E2E & INTERACTION TESTING
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# Gameplay Flow Tests:               🔴 NOT STARTED (0/7)
# User Interaction Tests:            🔴 NOT STARTED (0/6)
# Settings & Config Tests:           🔴 NOT STARTED (0/6)
# Navigation & Menu Tests:           🔴 NOT STARTED (0/6)
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# Total E2E Tests:                   🔴 NOT STARTED (0/25)
#
# ACCESSIBILITY TESTING (WCAG 2.1 AA)
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# Keyboard Navigation Tests:         🔴 NOT STARTED (0/11)
# Focus Management Tests:            🔴 NOT STARTED (0/6)
# Color Contrast Audit:              🟡 PENDING MANUAL
# Semantic HTML Audit:               🟡 PENDING MANUAL
# axe-core Automated Audit:          🔴 NOT STARTED (0 violations)
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# Total A11y Tests:                  🔴 NOT STARTED (0/17)
#
# PERFORMANCE TESTING
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# Rendering Performance:             🔴 NOT STARTED (0/3)
# Interaction Latency:               🔴 NOT STARTED (0/4)
# Bundle Size:                       🔴 NOT STARTED (0/4)
# Memory Usage:                      🔴 NOT STARTED (0/3)
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# Total Perf Tests:                  🔴 NOT STARTED (0/10)
#
# RESPONSIVE DESIGN TESTING (5 TIERS)
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# Mobile 320px (xs):                 🔴 NOT TESTED
# Mobile 375px (sm):                 🔴 NOT TESTED
# Tablet 600px (md):                 🔴 NOT TESTED
# Desktop 900px (lg):                🔴 NOT TESTED
# Widescreen 1200px (xl):            🔴 NOT TESTED
# Ultrawide 1800px (xxl):            🔴 NOT TESTED
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# Total Breakpoint Tests:            🔴 NOT TESTED (0/6)
#
# CROSS-PLATFORM TESTING
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# Web (Vite dev server):             🔴 NOT TESTED
# Electron (Desktop):                🔴 NOT TESTED
# Capacitor iOS:                     🔴 NOT TESTED
# Capacitor Android:                 🔴 NOT TESTED
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# Total Platform Tests:              🔴 NOT TESTED (0/4)
#
# ═══════════════════════════════════════════════════════
# OVERALL AUDIT STATUS:              🔴 NOT STARTED
# Total Tests to Build:              📊 69 tests
# Total Manual Checks:               📋 20+ checks
# ═══════════════════════════════════════════════════════
# ```
#
# ### 11.3 Next Steps (Immediate)
#
# 1. **Create Component Test Files** (1-2 hours)
#    - [ ] Create `.component.test.tsx` for all atoms/molecules/organisms
#    - [ ] Add basic render + props tests
#    - [ ] Add event handler tests
#    - [ ] Run `pnpm test` to verify
#
# 2. **Create E2E Test Files** (2-3 hours)
#    - [ ] Create `gameplay.e2e.spec.ts`
#    - [ ] Create `keyboard-nav.a11y.spec.ts`
#    - [ ] Create `responsive.e2e.spec.ts`
#    - [ ] Create `focus-management.a11y.spec.ts`
#    - [ ] Run `pnpm test:e2e` to verify
#
# 3. **Run Accessibility Audit** (1 hour)
#    - [ ] Create `axe-audit.a11y.spec.ts`
#    - [ ] Run Playwright accessibility tests
#    - [ ] Document violations found
#
# 4. **Review Findings** (1-2 hours)
#    - [ ] Analyze test results
#    - [ ] Identify accessibility gaps
#    - [ ] Create remediation plan
#
# 5. **Implement Fixes** (Variable - depends on findings)
#    - [ ] Fix keyboard navigation issues
#    - [ ] Fix focus management
#    - [ ] Fix color contrast
#    - [ ] Fix semantic HTML
#    - [ ] Re-test to verify fixes
#
# ### 11.4 Success Criteria
#
# ✅ **Testing Complete When**:
#
# - [ ] All 69 tests written and passing
# - [ ] 100% accessibility tests passing (axe-core 0 violations)
# - [ ] All 5 responsive breakpoints tested
# - [ ] All 4 platforms tested (Web, Electron, iOS, Android)
# - [ ] Performance benchmarks within targets
# - [ ] Coverage report >80% for critical code paths
# - [ ] Full `pnpm validate` passes
#
# ✅ **Accessibility Compliant When**:
#
# - [ ] WCAG 2.1 AA Level 2 achieved
# - [ ] All keyboard navigation tests pass
# - [ ] All focus management tests pass
# - [ ] All color contrast checks pass (≥4.5:1)
# - [ ] All semantic HTML correct
# - [ ] axe-core audit: 0 violations
# - [ ] Manual accessibility checklist completed
#
# ### 11.5 Estimated Timeline
#
# | Phase | Duration | Status |
# |-------|----------|--------|
# | Test Infrastructure Setup | Complete | ✅ Done |
# | Component Tests Build | 2-3 hours | ⏳ Next |
# | E2E/A11y Tests Build | 2-3 hours | ⏳ Next |
# | Accessibility Audit | 1-2 hours | ⏳ Next |
# | Issue Analysis | 1-2 hours | ⏳ Next |
# | Remediation Work | Variable | ⏳ Next |
# | Verification & Sign-off | 1-2 hours | ⏳ Next |
# | **TOTAL** | **8-15 hours** | **⏳ IN PROGRESS** |
#
# ---
#
# **Document Created**: March 18, 2026
# **Last Updated**: March 18, 2026
# **Status**: Framework Ready / Testing Pending
# **Owner**: Blackjack QA & Accessibility Team
